# %%
import nglview as nv
import mdtraj as md
t = md.load(nv.datafiles.XTC, top=nv.datafiles.GRO)
w = nv.show_mdtraj(t)
w

# %%
w.add_component('./3pqr.pdb')

# %%
w.orientation = [[43.890329751328345, -77.11662453612402, 105.58814320025495],
 [-0.22853809362964916, 0.7828318563225963, 0.5787440060049287],
 [16.003904342651367, -16.220169067382812, -44.552754402160645],
 [21.754983109003465, 2.072526372975452, -10.267155920852153]]

# %%
w.render_image()

# %%
w._display_image()
