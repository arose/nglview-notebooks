# %% [markdown]
# ## See also
#
# [pytraj example](pytraj.ipynb)
#
# [mdtraj example](mdtraj.ipynb)
#
# [MDAnalysis example](mdanalysis.ipynb)
#
# [membrane](membrane/sim.ipynb)

# %%
import nglview as nv

view = nv.show_structure_file('./3pqr.pdb')
view

# %%
view.add_component('./3pqr.ccp4.gz')

# %%
view.component_1.add_surface(opacity=0.2, wireframe=True, color='blue')

# %%
view.remove_component(view[1].id)

# %%
view.add_surface(opacity=0.3)

# %%
view.render_image()

# %%
view._display_image()
