# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

import nglview as nv
import MDAnalysis as mda
u = mda.Universe(nv.datafiles.GRO, nv.datafiles.XTC)
prot = u.select_atoms('protein')
w = nv.show_mdanalysis(prot)
w

# %%
w.add_component('./3pqr.pdb')

# %%
w.add_component('./3pqr.ccp4.gz')

# %%
w.component_2.clear()
w.component_2.add_surface(opacity=0.2, wireframe=True, color='blue')

# %%
w.orientation = [[-9.757692837890016, 74.73864812251843, -33.521904161172635],
 [0.3148424422445475, -0.40318087184734347, -0.8592551548509294],
 [24.06708335876465, -14.215036392211914, -44.552754402160645],
 [16.437398911242884, 14.0151089185114, 4.569105190669241]]

# %%
w.render_image()

# %%
w._display_image()
